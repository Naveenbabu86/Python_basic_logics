# %%
num = 0
result = 0
addvalue = 0
end = 10
while num <= end:
    result = num**2 + result
    addvalue = num+addvalue
    num += 1
print("square:",result)
print("addvalue:",addvalue**addvalue)
print("difference:",result-addvalue)
# Out:
# square: 385
# addvalue: 524744532468751923546122657597368049278513737089035272057324643668607677682302892208099365234375
# difference: 330
