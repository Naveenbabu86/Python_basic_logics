# %%
"""
Input:  "swiss"
Output: "w"

"""

input = "swiss"
dict = {}

for i in input:
    if i in dict:
        dict[i] +=1
    else:
        dict[i] = 1
print(dict)

for keys,values in dict.items():
    if values == 1:
        print(keys)
        break
# Out:
# {'s': 3, 'w': 1, 'i': 1}
# w
