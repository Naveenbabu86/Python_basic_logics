# %%
"""
Write a Python function that takes a string and returns the number of vowels (a, e, i, o, u) in it.

Example:

Input: "hello world"
Output: 3

"""

input = "hello world"

l = ["a","e","i","o","u"]
vowels = 0

for i in input:
    if i in l:
        vowels +=1
print(vowels)
# Out:
# 3
