# %%
text = 120
new_text = str(text)
reversed_text = ""
for i in new_text:
    reversed_text = i + reversed_text
    print(reversed_text) 
if reversed_text == new_text:
    print("Palindrome:", reversed_text)
else:
    print("Not a Palindrome:", reversed_text)
# Out:
# 1
# 21
# 021
# Not a Palindrome: 021
