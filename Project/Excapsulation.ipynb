# %%
class Student:
    """
    Defines the student attributes
    """
    def __init__(self,s_id : str, s_name: str, s_address: str):
        self._id = s_id
s = Student("123","Naveen","Guntur")
print(s._id)
# Out:
# 123

# %%
"9"+"10"+""
# Out:
# '910'

# %%
string = ""+"9"+"10"

# %%
string
# Out:
# '910'

# %%
string+"23"
# Out:
# '91023'
