# %%
"""
Input: "abcdf"
Output: "e"

"""

input = "abcdf"

for i in range(0,len(input)-1):
    if ord(input[i])+1 != ord(input[i+1]):
        print(ord(input[i])+1)
        print(ord(input[i+1]))
        print("missing value is :", chr(ord(input[i+1])-1))
        break
# Out:
# 101
# 102
# missing value is : e
