# %%
l = [1, 3, 4, 2, 6, 7, 3, 8, 4, 9,5,3,8,2,6,4]

target = 10
seen = set()
result =set()
for i in l:
    value = target - i
    if value not in seen:
        seen.add(i)
    else:
        pair = tuple(sorted((i,value)))
        result.add(pair)
print(result)
# Out:
# {(3, 7), (4, 6), (1, 9), (2, 8)}
