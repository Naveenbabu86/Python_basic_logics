# %%
nums = [2, 7, 11, 15, -2, 9]
target = 9
seen = set()
pair_data = set()
for i in nums:
    value = target - i
    if value in seen:
        pair = tuple(sorted((i,value)))
        pair_data.add(pair)
    seen.add(i)
print(pair_data)
# Out:
# {(-2, 11), (2, 7)}
